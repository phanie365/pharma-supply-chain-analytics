# %%
# %sql show catalogs

# %% [markdown]
# Creer le catalogue

# %%
# %sql
CREATE CATALOG IF NOT EXISTS pharma_catalog;

# %% [markdown]
# Creer les schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS pharma_catalog.bronze;
CREATE SCHEMA IF NOT EXISTS pharma_catalog.silver;
CREATE SCHEMA IF NOT EXISTS pharma_catalog.silver_quarantine;
CREATE SCHEMA IF NOT EXISTS pharma_catalog.gold;

# %%
# %sql
SHOW SCHEMAS IN pharma_catalog;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS pharma_catalog.landing;

# %%
# %sql
CREATE VOLUME IF NOT EXISTS pharma_catalog.landing.raw;
